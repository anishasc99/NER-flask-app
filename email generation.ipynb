# %%
from random import randint
import pandas as pd
import locale

locale.setlocale(locale.LC_ALL, 'en_IN')

# df = pd.read_csv("products.csv")
#df2 = pd.read_excel("Ingram Product.xlsx")
#df2.drop(0,inplace=True)
# print(df2)
products = ["Methylene","Acetylene","Grignard","Benzolide","Ethoxide"]
# import code; code.interact(local=dict(globals(), **locals()))
# SKU = list(df2['SKU'])
# print(new_products,SKU)
# products.extend(list(df['product']))
# products = list(df['product'])
# print(products)
Names = ["Manager","CEO"]
Users = ["Mayur","Dhaval"]
greetings = ["Hey, NAME","Hi, NAME","Dear,NAME","Hello, NAME"]
#message_product = ["number x name,", "name x number,", "number of name,", "number x name ", "name x number ", "number of name ", "name, number ", "name number","number name","XXX. name x number","XXX. number x name","XXX. number of name"]
message_product = ["number name respectively","number of name,"]
message_body = ["I want to buy different product from you. Can you please share the details of the products. Products Names and quantities are listed in below.","    I am looking for differents products from you. Their quantity and products Names are "]
regrads = ["Very truly yours,","Respectfully,","Yours truly,","Sincerely yours,","Sincerely,"]


def gen_greetings():
    greeting = greetings[randint(0,len(greetings)-1)]
    greeting = greeting.replace("NAME",Names[randint(0,len(Names)-1)])
    return greeting

def gen_products(num_products):
    nums = []
    for _ in range(num_products):
        rnd = randint(0,len(products)-1)
        if  rnd not in nums:
            nums.append(rnd)
    prods = [products[i] for i in nums]
    # print(prods)
    return prods
        

def gen_msg(i):
    index = randint(0,len(message_product)-1)
    if i in range(0,3):
        start_body = message_body[1]
    else:
        start_body = message_body[0]+"\n"
   # msg = message_product[i]
    msg = message_product[i%2]
    # msg = message[7]
    new_msg = start_body+msg
    product_list = gen_products(randint(1,10))
    if "number x name," in msg:
        for product in product_list:
            new_msg = new_msg.replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + ' ' + msg
        new_msg = new_msg.replace(msg, '')
        new_msg = new_msg[:-2]+"."
    
    elif "name x number," in msg:
        for product in product_list:
            new_msg = new_msg.replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + ' ' + msg
        new_msg = new_msg.replace(msg, '')
        new_msg = new_msg[:-2]+"."
    
    elif "number of name," in msg:
        for product in product_list:
            new_msg = new_msg.replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + ' ' + msg
        new_msg = new_msg.replace(msg, '')
        new_msg = new_msg[:-2]+"."
    
    elif "number x name " in msg:
        for product in product_list:
            new_msg = new_msg.replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + '\n' + msg
        new_msg = new_msg.replace(msg, '')
        new_msg = new_msg[:-2]+"."
    elif "number name respectively" in msg:
        new_msg = start_body
        numbers = ""
        for i in range(len(product_list)):
            numbers += str(randint(10,10000))+", "
        new_msg +=numbers[:-2] +" of "
        add_message = ""
        for prod in product_list:
            add_message += prod+", "
        #print(numbers)
        new_msg += add_message[:-2] + " respectively."
    
    elif "name x number " in msg:
        for product in product_list:
            new_msg = new_msg.replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + '\n' + msg
        new_msg = new_msg.replace(msg, '')
        new_msg = new_msg[:-2]+"."
    
    elif "number of name " in msg:
        for product in product_list:
            new_msg = new_msg.replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + '\n' + msg
        new_msg = new_msg.replace(msg, '')
        new_msg = new_msg[:-2]+"."
    
    elif "name, number " in msg:
        for product in product_list:
            new_msg = new_msg.replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + '\n' + msg
        new_msg = new_msg.replace(msg, '')
        new_msg = new_msg[:-2]+"."
    
    elif "name number" in msg:
        for product in product_list:
            new_msg = new_msg.replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + '\n' + msg
        new_msg = new_msg.replace(msg, '')
        print(new_msg)
        new_msg = new_msg[:-2]+"."
    elif "number name" in msg:
        for product in product_list:
            new_msg = new_msg.replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + '\n' + msg
        new_msg = new_msg.replace(msg, '')
        print(new_msg)
        new_msg = new_msg[:-2]+"."
    elif "XXX. name x number" in msg:
        for count,product in enumerate(product_list):
            new_msg = new_msg.replace("XXX",str(count+1)).replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + '\n' + msg
        new_msg = new_msg.replace(msg, '')
        print(new_msg)
        new_msg = new_msg[:-2]+"."
    elif "XXX. number x name" in msg:
        for count,product in enumerate(product_list):
            new_msg = new_msg.replace("XXX",str(count+1)).replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + '\n' + msg
        new_msg = new_msg.replace(msg, '')
        print(new_msg)
        new_msg = new_msg[:-2]+"."
    elif "XXX. number of name" in msg:
        for count,product in enumerate(product_list):
            new_msg = new_msg.replace("XXX",str(count+1)).replace("number", str(locale.format("%d", randint(10,10000), grouping=True))).replace('name', str(product)) + '\n' + msg
        new_msg = new_msg.replace(msg, '')
        print(new_msg)
        new_msg = new_msg[:-2]+"."
   
    return new_msg

def gen_regrads():
    reg = regrads[randint(0,len(regrads)-1)]+"\n"+"USER"
    reg = reg.replace("USER",Users[randint(0,len(Users)-1)])
    return reg

if __name__=="__main__":
    for i in range(13,23):
        email = ""
        email+=gen_greetings()+"\n"
        email+=gen_msg(i-1)+"\n"
        email+=gen_regrads()
        # f = open("new-email/email-351-400/email_"+str(i)+".txt","w+")
        print(email)
        f= open("mails/email_"+str(i)+".txt","w+")
        f.write(email)
# Out:
# Dear,Manager
# I want to buy different product from you. Can you please share the details of the products. Products Names and quantities are listed in below.
# 7208, 4454, 4395 of Ethoxide, Acetylene, Benzolide respectively.
# Sincerely yours,
# Dhaval
# Hey, Manager
# I want to buy different product from you. Can you please share the details of the products. Products Names and quantities are listed in below.
# 7,839 of Ethoxide.
# Very truly yours,
# Dhaval
# Hey, CEO
# I want to buy different product from you. Can you please share the details of the products. Products Names and quantities are listed in below.
# 7526, 6829, 3371 of Benzolide, Grignard, Methylene respectively.
# Very truly yours,
# Dhaval
# Dear,Manager
# I want to buy different product from you. Can you please share the details of the products. Products Names and quantities are listed in below.
# 36 of Ethoxide, 4,471 of Benzolide, 4,758 of Methylene.
# Sincerely yours,
# Mayur
# Hey, Manager
# ...
